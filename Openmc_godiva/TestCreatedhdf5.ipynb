# %%
import openmc
import math
import os
os.environ['OPENMC_CROSS_SECTIONS']='/home/rfp/kand/Openmc_godiva/hdf5_files/cross_sections.xml'
os.system('rm %s%output')
os.system('rm s*.h5')
import numpy as np
import matplotlib.pyplot as plt

def KandGodiva(particles):
    u02 = openmc.Material(1, "U235", temperature=293.6)
    # Add nuclides to uo2
    u02.add_nuclide('U235', 0.937)
    u02.add_nuclide('U234', 0.01)
    u02.add_nuclide('U238', 0.053)

    u02.set_density('g/cm3', 18.7)

    r_godiva=8.69696
    u02.volume = 4*math.pi*r_godiva**2/3


    mats = openmc.Materials([u02])
    mats.export_to_xml()

    fuel_or = openmc.Sphere(r=r_godiva)

    fuel_region = -fuel_or

    fuel = openmc.Cell(1, 'fuel')
    fuel.fill = u02
    fuel.region = fuel_region

    pitch = 50
    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='vacuum')
    right = openmc.XPlane(x0=pitch/2, boundary_type='vacuum')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='vacuum')
    top = openmc.YPlane(y0=pitch/2, boundary_type='vacuum')
    z1 = openmc.ZPlane(z0=pitch/2, boundary_type='vacuum')
    z2 = openmc.ZPlane(z0=-pitch/2, boundary_type='vacuum')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of fuel outer cylinder
    outer_region = +left & -right & +bottom & -top & +fuel_or & -z1 & +z2

    outer = openmc.Cell(name='outer')
    outer.region = outer_region

    root = openmc.Universe(cells=(fuel, outer))

    geom = openmc.Geometry()
    geom.root_universe = root
    geom.export_to_xml()

    point = openmc.stats.Point((0, 0, 0))
    src = openmc.Source(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = particles
    settings.output = {'tallies': False}
    settings.export_to_xml()

    model = openmc.model.Model(geom, mats, settings)
    
    return model

"""
particles_vector=[100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000, 25000, 50000, 75000, 100000, 250000, 500000, 1000000]
keff_vector=[]
for particles in particles_vector:
    output=KandGodiva(particles).run()
    keff_vector.append(openmc.StatePoint(output).k_combined.nominal_value)

plt.plot(particles_vector, keff_vector)
plt.title('k value depending on the amount of particles in each batch')
plt.xlabel('Particles')
plt.ylabel('k value')
plt.savefig('openmcplot.png')
"""

def Ace_to_hdf5(dir_ace,dir_hdf5,ace_files):
    
    ace_files=[]

    os.chdir(dir_ace)
    for entry in os.scandir('.'):
        if entry.is_file() and ".ace" in entry.name:
            ace_files.append(str(entry.name))

    ace_files=sorted(ace_files)
    print(ace_files)
    for ace_file in ace_files:
        if os.path.isfile('U235.h5'):#If files already exist remove
            os.remove('U235.h5')
        if os.path.isfile('cross_sections.xml'):#If files already exist remove
            os.remove('cross_sections.xml')
        os.chdir(dir_ace) #Make sure dir is with all ace files
        U235 = openmc.data.IncidentNeutron.from_ace(ace_file)
        os.chdir(dir_hdf5) #The hdf5 files is created in the right folder
        U235.export_to_hdf5(f'U235.h5')

        #Create library
        library = openmc.data.DataLibrary()
        library.register_file(U235.h5)
        library.register_file('U234.h5')
        library.register_file('U238.h5')
        library.export_to_xml()
        return

def main():
    
    ace_files=[]
    k_effs=[]
    dir_ace='/home/rfp/kand/U235.nuss.10.10.2016'
    dir_hdf5='/home/rfp/kand/Openmc_godiva/hdf5_files'
    kand_dir='/home/rfp/kand'

    os.chdir(dir_ace)
    for entry in os.scandir('.'):
        if entry.is_file() and ".ace" in entry.name:
            ace_files.append(str(entry.name))

    ace_files=sorted(ace_files)
   
    for ace_file in ace_files:
        os.chdir(dir_hdf5)
        if os.path.isfile('U235.h5'):#If files already exist remove
            os.remove('U235.h5')
        if os.path.isfile('cross_sections.xml'):#If files already exist remove
            os.remove('cross_sections.xml')
        os.chdir(dir_ace) #Make sure dir is with all ace files
        U235 = openmc.data.IncidentNeutron.from_ace(ace_file)
        os.chdir(dir_hdf5) #The hdf5 files is created in the right folder
        U235.export_to_hdf5('U235.h5')

        #Create library
        library = openmc.data.DataLibrary()
        library.register_file('U235.h5')
        library.register_file('U234.h5')
        library.register_file('U238.h5')
        library.export_to_xml()
        os.chdir(kand_dir)
        output=KandGodiva(600000).run()
        keff=openmc.StatePoint(output).k_combined.nominal_value
        k_effs.append(keff)
        print(keff)

        print(k_effs)

if __name__ == '__main__':
    main()
# Out:
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2023-04-12 16:22:56
#     OpenMP Threads | 4
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U235 from /home/rfp/kand/Openmc_godiva/hdf5_files/U235.h5
#  Reading U234 from /home/rfp/kand/Openmc_godiva/hdf5_files/U234.h5
#  Reading U238 from /home/rfp/kand/Openmc_godiva/hdf5_files/U238.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 293.0 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.33831
#         2/1    1.14305
#         3/1    1.06349
#         4/1    1.02331
#         5/1    1.00885
#         6/1    1.00002
#         7/1    0.99523
#         8/1    0.99324
#         9/1    0.99532
#        10/1    0.99335
#        11/1    0.99430
#        12/1    0.99459    0.99445 +/- 0.00015
#        13/1    0.99394    0.99428 +/- 0.00019
#        14/1    0.99416    0.99425 +/- 0.00014
#        15/1    0.99207    0.99381 +/- 0.00045
#        16/1    0.99212    0.99353 +/- 0.00046
#        17/1    0.99317    0.99348 +/- 0.00039
#        18/1    0.99341    0.99347 +/- 0.00034
#        19/1    0.99482    0.99362 +/- 0.00034
#        20/1    0.99389    0.99365 +/- 0.00030
#        21/1    0.99367    0.99365 +/- 0.00027
#        22/1    0.99294    0.99359 +/- 0.00026
#        23/1    0.99416    0.99364 +/- 0.00024
#        24/1    0.99067    0.99342 +/- 0.00031
#        85/1    0.99285    0.99361 +/- 0.00013
#        86/1    0.99358    0.99361 +/- 0.00013
#        87/1    0.99279    0.99360 +/- 0.00013
#        88/1    0.99249    0.99359 +/- 0.00013
#        89/1    0.99156    0.99356 +/- 0.00013
#        90/1    0.99279    0.99355 +/- 0.00013
#        91/1    0.99115    0.99352 +/- 0.00013
#        92/1    0.99374    0.99353 +/- 0.00013
#        93/1    0.99315    0.99352 +/- 0.00012
#        94/1    0.99342    0.99352 +/- 0.00012
#        95/1    0.99160    0.99350 +/- 0.00012
#        96/1    0.99256    0.99349 +/- 0.00012
#        97/1    0.99395    0.99349 +/- 0.00012
#        98/1    0.99385    0.99350 +/- 0.00012
#        99/1    0.99297    0.99349 +/- 0.00012
#       100/1    0.99448    0.99350 +/- 0.00012
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 8.2484e-01 seconds
#    Reading cross sections          = 7.5600e-01 seconds
#  Total time in simulation          = 1.1951e+02 seconds
#    Time in transport only          = 9.8563e+01 seconds
#    Time in inactive batches        = 1.9434e+01 seconds
#    Time in active batches          = 1.0008e+02 seconds
#    Time synchronizing fission bank = 1.6332e+01 seconds
#      Sampling source sites         = 1.5504e+01 seconds
#      SEND/RECV source sites        = 8.2675e-01 seconds
#    Time accumulating tallies       = 1.4717e-04 seconds
#    Time writing statepoints        = 1.0007e-01 seconds
#  Total time for finalization       = 7.6800e-07 seconds
#  Total time elapsed                = 1.2101e+02 seconds
#  Calculation Rate (inactive)       = 308736.0 particles/second
#  Calculation Rate (active)         = 539575.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.99347 +/- 0.00015
#  k-effective (Track-length)  = 0.99350 +/- 0.00012
#  k-effective (Absorption)    = 0.99344 +/- 0.00015
#  Combined k-effective        = 0.99348 +/- 0.00009
#  Leakage Fraction            = 0.57568 +/- 0.00007
#
# 0.993483547695267
# [0.993483547695267]
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2023-04-12 16:24:59
#     OpenMP Threads | 4
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U235 from /home/rfp/kand/Openmc_godiva/hdf5_files/U235.h5
#  Reading U234 from /home/rfp/kand/Openmc_godiva/hdf5_files/U234.h5
#  Reading U238 from /home/rfp/kand/Openmc_godiva/hdf5_files/U238.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 293.0 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.32413
#         2/1    1.13264
#         3/1    1.05461
#         4/1    1.01445
#         5/1    0.99873
#         6/1    0.99370
#         7/1    0.98856
#         8/1    0.98592
#         9/1    0.98648
#        10/1    0.98323
#        11/1    0.98546
#        12/1    0.98382    0.98464 +/- 0.00082
#        13/1    0.98463    0.98464 +/- 0.00048
#        14/1    0.98430    0.98455 +/- 0.00035
#        15/1    0.98573    0.98479 +/- 0.00036
#        16/1    0.98430    0.98471 +/- 0.00030
#        77/1    0.98533    0.98478 +/- 0.00012
#        78/1    0.98529    0.98479 +/- 0.00012
#        79/1    0.98523    0.98480 +/- 0.00011
#        80/1    0.98633    0.98482 +/- 0.00012
#        81/1    0.98498    0.98482 +/- 0.00011
#        82/1    0.98454    0.98482 +/- 0.00011
#        83/1    0.98431    0.98481 +/- 0.00011
#        84/1    0.98633    0.98483 +/- 0.00011
#        85/1    0.98560    0.98484 +/- 0.00011
#        86/1    0.98339    0.98482 +/- 0.00011
#        87/1    0.98481    0.98482 +/- 0.00011
#        88/1    0.98400    0.98481 +/- 0.00011
#        89/1    0.98365    0.98480 +/- 0.00011
#        90/1    0.98381    0.98478 +/- 0.00011
#        91/1    0.98176    0.98475 +/- 0.00011
#        92/1    0.98353    0.98473 +/- 0.00011
#        93/1    0.98381    0.98472 +/- 0.00011
#        94/1    0.98529    0.98473 +/- 0.00011
#        95/1    0.98384    0.98472 +/- 0.00011
#        96/1    0.98547    0.98472 +/- 0.00011
#        97/1    0.98422    0.98472 +/- 0.00011
#        98/1    0.98302    0.98470 +/- 0.00011
#        99/1    0.98489    0.98470 +/- 0.00011
#       100/1    0.98559    0.98471 +/- 0.00011
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 7.3865e-01 seconds
#    Reading cross sections          = 6.5683e-01 seconds
#  Total time in simulation          = 1.1080e+02 seconds
#    Time in transport only          = 9.3066e+01 seconds
#    Time in inactive batches        = 1.4432e+01 seconds
#    Time in active batches          = 9.6368e+01 seconds
#    Time synchronizing fission bank = 1.3486e+01 seconds
#      Sampling source sites         = 1.2662e+01 seconds
#      SEND/RECV source sites        = 8.2323e-01 seconds
#    Time accumulating tallies       = 1.8188e-04 seconds
#    Time writing statepoints        = 9.3339e-02 seconds
#  Total time for finalization       = 7.5200e-07 seconds
#  Total time elapsed                = 1.1202e+02 seconds
#  Calculation Rate (inactive)       = 415754.0 particles/second
#  Calculation Rate (active)         = 560353.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.98473 +/- 0.00013
#  k-effective (Track-length)  = 0.98471 +/- 0.00011
#  k-effective (Absorption)    = 0.98508 +/- 0.00015
#  Combined k-effective        = 0.98484 +/- 0.00009
#  Leakage Fraction            = 0.57329 +/- 0.00006
#
# 0.9848445906553273
# [0.993483547695267, 0.9848445906553273]
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2023-04-12 16:26:53
#     OpenMP Threads | 4
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U235 from /home/rfp/kand/Openmc_godiva/hdf5_files/U235.h5
#  Reading U234 from /home/rfp/kand/Openmc_godiva/hdf5_files/U234.h5
#  Reading U238 from /home/rfp/kand/Openmc_godiva/hdf5_files/U238.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 293.0 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1
#        68/1    0.99371    0.99316 +/- 0.00014
#        69/1    0.99431    0.99318 +/- 0.00014
#        70/1    0.99174    0.99315 +/- 0.00014
#        71/1    0.99243    0.99314 +/- 0.00013
#        72/1    0.99180    0.99312 +/- 0.00013
#        73/1    0.99307    0.99312 +/- 0.00013
#        74/1    0.99182    0.99310 +/- 0.00013
#        75/1    0.99355    0.99310 +/- 0.00013
#        76/1    0.99262    0.99310 +/- 0.00013
#        77/1    0.99577    0.99314 +/- 0.00013
#        78/1    0.99433    0.99315 +/- 0.00013
#        79/1    0.99350    0.99316 +/- 0.00013
#        80/1    0.99311    0.99316 +/- 0.00013
#        81/1    0.99377    0.99317 +/- 0.00013
#        82/1    0.99285    0.99316 +/- 0.00012
#        83/1    0.99237    0.99315 +/- 0.00012
#        84/1    0.99103    0.99312 +/- 0.00012
#        85/1    0.99547    0.99315 +/- 0.00013
#        86/1    0.99405    0.99317 +/- 0.00013
#        87/1    0.99314    0.99317 +/- 0.00012
#        88/1    0.99218    0.99315 +/- 0.00012
#        89/1    0.99138    0.99313 +/- 0.00012
#        90/1    0.99350    0.99314 +/- 0.00012
#        91/1    0.99185    0.99312 +/- 0.00012
#        92/1    0.99259    0.99311 +/- 0.00012
#        93/1    0.99145    0.99309 +/- 0.00012
#        94/1    0.99168    0.99308 +/- 0.00012
#        95/1    0.99192    0.99306 +/- 0.00012
#        96/1    0.99330    0.99306 +/- 0.00012
#        97/1    0.98998    0.99303 +/- 0.00012
#        98/1    0.99344    0.99303 +/- 0.00012
#        99/1    0.99315    0.99304 +/- 0.00012
#       100/1    0.99440    0.99305 +/- 0.00012
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.7811e-01 seconds
#    Reading cross sections          = 5.3197e-01 seconds
#  Total time in simulation          = 1.1810e+02 seconds
#    Time in transport only          = 1.0174e+02 seconds
#    Time in inactive batches        = 1.1159e+01 seconds
#    Time in active batches          = 1.0694e+02 seconds
#    Time synchronizing fission bank = 1.2401e+01 seconds
#      Sampling source sites         = 1.1651e+01 seconds
#      SEND/RECV source sites        = 7.4961e-01 seconds
#    Time accumulating tallies       = 1.5175e-04 seconds
#    Time writing statepoints        = 8.4444e-02 seconds
#  Total time for finalization       = 4.6800e-07 seconds
#  Total time elapsed                = 1.1909e+02 seconds
#  Calculation Rate (inactive)       = 537687.0 particles/second
#  Calculation Rate (active)         = 504973.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.99289 +/- 0.00014
#  k-effective (Track-length)  = 0.99305 +/- 0.00012
#  k-effective (Absorption)    = 0.99298 +/- 0.00014
#  Combined k-effective        = 0.99306 +/- 0.00009
#  Leakage Fraction            = 0.57498 +/- 0.00006
#
# 0.9930565360805824
# [0.993483547695267, 0.9848445906553273, 0.9930565360805824]
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/data/reaction.py:1006: UserWarning: Negative cross sections found for MT=4 in 92235.00c. Setting to zero.
#   warn("Negative cross sections found for MT={} in {}. Setting "
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12
particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.99678 +/- 0.00013
#  k-effective (Track-length)  = 0.99684 +/- 0.00011
#  k-effective (Absorption)    = 0.99706 +/- 0.00016
#  Combined k-effective        = 0.99692 +/- 0.00010
#  Leakage Fraction            = 0.57961 +/- 0.00007
#
# 0.9969152623054934
# [0.993483547695267, 0.9848445906553273, 0.9930565360805824, 0.9969152623054934]
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2023-04-12 16:31:01
#     OpenMP Threads | 4
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U235 from /home/rfp/kand/Openmc_godiva/hdf5_files/U235.h5
#  Reading U234 from /home/rfp/kand/Openmc_godiva/hdf5_files/U234.h5
#  Reading U238 from /home/rfp/kand/Openmc_godiva/hdf5_files/U238.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 293.0 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.38475
#         2/1    1.17657
#         3/1    1.09151
#         4/1    1.05339
#         5/1    1.03679
#         6/1    1.02841
#         7/1    1.02680
#         8/1    1.02369
#         9/1    1.02309
#        10/1    1.02373
#        11/1    1.02282
#        12/1    1.02365    1.02323 +/- 0.00042
#        13/1    1.02132    1.02259 +/- 0.00068
#        14/1    1.02067    1.02211 +/- 0.00068
#        15/1    1.01960    1.02161 +/- 0.00073
#        16/1    1.02279    1.02181 +/- 0.00063
#        17/1    1.02159    1.02178 +/- 0.00053
#        18/1    1.02023    1.02158 +/- 0.00050
#        19/1    1.02477    1.02194 +/- 0.00056
#        20/1    1.02286    1.02203 +/- 0.00051
#        21/1    1.02155    1.02199 +/- 0.00047
#        22/1    1.02292    1.02206 +/- 0.00043
#        23/1    1.02315    1.02215 +/- 0.00041
#        24/1    1.02310    1.02221 +/- 0.00038
#        25/1    1.02070    1.02211 +/- 0.00037
#        26/1    1.02243    1.02213 +/- 0.00035
#        27/1    1.02234    1.02215 +/- 0.00033
#        28/1    1.02235    1.02216 +/- 0.00031
#        29/1    1.02183    1.02214 +/- 0.00029
#        30/1    1.02297    1.02218 +/- 0.00028
#        31/1    1.02375    1.02226 +/- 0.00028
#        32/1    1.02155    1.02222 +/- 0.00027
#        33/1    1.02342    1.02228 +/- 0.00026
#        34/1    1.02000    1.02218 +/- 0.00027
#        35/1    1.02092    1.02213 +/- 0.00026
#        36/1    1.02253    1.02215 +/- 0.00025
#        37/1    1.02177    1.02213 +/- 0.00024
#        38/1    1.02245    1.02214 +/- 0.00023
#        39/1    1.02382    1.02220 +/- 0.00023
#        40/1    1.02461    1.02228 +/- 0.00024
#        41/1    1.02158    1.02226 +/- 0.00023
#        42/1    1.02181    1.02224 +/- 0.00022
#        43/1    1.02298    1.02227 +/- 0.00022
#        44/1    1.02258    1.02228 +/- 0.00021
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0993e+00 seconds
#    Reading cross sections          = 1.0678e+00 seconds
#  Total time in simulation          = 1.3116e+02 seconds
#    Time in transport only          = 1.1046e+02 seconds
#    Time in inactive batches        = 1.4757e+01 seconds
#    Time in active batches          = 1.1641e+02 seconds
#    Time synchronizing fission bank = 1.6279e+01 seconds
#      Sampling source sites         = 1.5446e+01 seconds
#      SEND/RECV source sites        = 8.3295e-01 seconds
#    Time accumulating tallies       = 1.9434e-04 seconds
#    Time writing statepoints        = 7.6872e-02 seconds
#  Total time for finalization       = 5.1600e-07 seconds
#  Total time elapsed                = 1.3286e+02 seconds
#  Calculation Rate (inactive)       = 406583.0 particles/second
#  Calculation Rate (active)         = 463894.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.02208 +/- 0.00014
#  k-effective (Track-length)  = 1.02217 +/- 0.00012
#  k-effective (Absorption)    = 1.02239 +/- 0.00017
#  Combined k-effective        = 1.02228 +/- 0.00010
#  Leakage Fraction            = 0.58433 +/- 0.00007
#
# 1.0222773244133994
# [0.993483547695267, 0.9848445906553273, 0.9930565360805824, 0.9969152623054934, 1.0222773244133994]
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2023-04-12 16:33:15
#     OpenMP Threads | 4
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U235 from /home/rfp/kand/Openmc_godiva/hdf5_files/U235.h5
#  Reading U234 from /home/rfp/kand/Openmc_godiva/hdf5_files/U234.h5
#  Reading U238 from /home/rfp/kand/Openmc_godiva/hdf5_files/U238.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 293.0 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.33651
#         2/1    1.14072
#         3/1    1.05920
#         4/1    1.02148
#         5/1    1.00779
#         6/1    0.99668
#         7/1    0.99431
#         8/1    0.99196
#         9/1    0.99213
#        10/1    0.99082
#        11/1    0.99236
#        12/1    0.99135    0.99186 +/- 0.00050
#        13/1    0.99042    0.99138 +/- 0.00056
#        14/1    0.99197    0.99153 +/- 0.00042
#        15/1    0.99209    0.99164 +/- 0.00035
#        16/1    0.99080    0.99150 +/- 0.00032
#        17/1    0.99274    0.99168 +/- 0.00032
#        18/1    0.98871    0.99131 +/- 0.00046
#        19/1    0.99066    0.99123 +/- 0.00041
#        20/1    0.99303    0.99141 +/- 0.00041
#        21/1    0.99213    0.99148 +/- 0.00038
#        22/1    0.99027    0.99138 +/- 0.00036
#        23/1    0.99261    0.99147 +/- 0.00034
#        24/1    0.99095    0.99143 +/- 0.00032
#        25/1    0.99011    0.99135 +/- 0.00031
#        26/1    0.98985    0.99125 +/- 0.00031
#        27/1    0.99094    0.99124 +/- 0.00029
#        28/1    0.98905    0.99111 +/- 0.00030
#        29/1    0.99104    0.99111 +/- 0.00028
#        30/1    0.99236    0.99117 +/- 0.00027
#        31/1    0.99217    0.99122 +/- 0.00027
#        32/1    0.99157    0.99124 +/- 0.00025
#        33/1    0.99237    0.99129 +/- 0.00025
#        34/1    0.99061    0.99126 +/- 0.00024
#        87/1    0.99082    0.99007 +/- 0.00011
#        88/1    0.99072    0.99008 +/- 0.00011
#        89/1    0.98925    0.99007 +/- 0.00011
#        90/1    0.99129    0.99009 +/- 0.00011
#        91/1    0.98669    0.99005 +/- 0.00012
#        92/1    0.98920    0.99004 +/- 0.00011
#        93/1    0.99072    0.99004 +/- 0.00011
#        94/1    0.99120    0.99006 +/- 0.00011
#        95/1    0.98948    0.99005 +/- 0.00011
#        96/1    0.98852    0.99003 +/- 0.00011
#        97/1    0.98888    0.99002 +/- 0.00011
#        98/1    0.98890    0.99001 +/- 0.00011
#        99/1    0.99110    0.99002 +/- 0.00011
#       100/1    0.99118    0.99003 +/- 0.00011
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.9830e-01 seconds
#    Reading cross sections          = 4.7333e-01 seconds
#  Total time in simulation          = 1.4382e+02 seconds
#    Time in transport only          = 1.2584e+02 seconds
#    Time in inactive batches        = 1.4824e+01 seconds
#    Time in active batches          = 1.2900e+02 seconds
#    Time synchronizing fission bank = 1.4080e+01 seconds
#      Sampling source sites         = 1.3295e+01 seconds
#      SEND/RECV source sites        = 7.8450e-01 seconds
#    Time accumulating tallies       = 1.5149e-04 seconds
#    Time writing statepoints        = 9.9914e-02 seconds
#  Total time for finalization       = 6.5500e-07 seconds
#  Total time elapsed                = 1.4460e+02 seconds
#  Calculation Rate (inactive)       = 404740.0 particles/second
#  Calculation Rate (active)         = 418609.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.98992 +/- 0.00014
#  k-effective (Track-length)  = 0.99003 +/- 0.00011
#  k-effective (Absorption)    = 0.98997 +/- 0.00016
#  Combined k-effective        = 0.99003 +/- 0.00009
#  Leakage Fraction            = 0.56876 +/- 0.00007
#
# 0.9900319469315197
# [0.993483547695267, 0.9848445906553273, 0.9930565360805824, 0.9969152623054934, 1.0222773244133994, 0.9912972370050633, 1.0074626150974915, 1.015609669770395, 0.9896179099642766, 1.0048249609716058, 1.0087224677575293, 0.9816503398480056, 0.9847009188919785, 0.9913153841639967, 0.9810371245771218, 1.0068974817307235, 1.0115867521937896, 0.9928370986960287, 0.9747081655367869, 0.991373661019558, 0.9851482613624557, 1.0053380025206733, 0.98631624564955, 0.9750650778657174, 1.0073648695276765, 1.0099809370769297, 1.002229342276266, 0.9843970144937226, 0.9846110253068349, 0.9798904069323533, 0.997712631990232, 0.9955560751508116, 0.974374104867594, 0.9861482889534356, 0.9884744295341907, 0.9955247424118671, 0.9853261216818388, 0.9956071940574711, 1.0038494690748043, 0.9872930784807128, 0.9721797791514929, 0.9988051695832034, 0.9943849681044195, 1.0016330018318098, 0.994557629974956, 0.9808319614306701, 0.9816074632773785, 1.0021483468215626, 1.0118771978586654, 0.9908889194057781, 0.9891376225108959, 0.9971704649908896, 0.9935707415714448, 0.9998501888915822, 0.9974038942723451, 1.01738152226187, 0.9797026110131473, 0.995638507360498, 0.9836822017591218, 1.0044725755096706, 0.9978022797309813, 1.0021483468216534, 0.9882451277325949, 0.9881548008628387, 1.001791559566723, 0.9874064397480232, 0.9864959321248492, 1.004001041008579, 1.0014889043485726, 0.9730940277767721, 0.9794884596879582, 0.9789291138427187, 0.9870817091271021, 0.9927704715919093, 0.9911166949203066, 0.9942148684043215, 0.9856568350892712, 0.9911187301575776, 0.9917416427047646, 0.9887608848766156, 0.9851685163952904, 0.9976565363546471, 1.0039497512580855, 0.9861962700052389, 0.9839064622927225, 0.9829397994899169, 0.9898071573444506, 0.9997621756146324, 0.9899995022574538, 0.99294051833654, 1.0186659072008328, 0.9845744597715519, 0.9979274952270015, 0.991499035254686, 1.0001948023911271, 1.0013496965327058, 0.9925682338482666, 0.9900319469315197]
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/rfp/anaconda3/envs/openmc-env/lib/python3.9/site-packages/openmc/mixin.py:68: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                    | The OpenMC Monte Carlo Code
#          Copyright | 2011-2021 MIT and OpenMC contributors
#            License | https://docs.openmc.org/en/latest/license.html
#            Version | 0.12.1
#           Git SHA1 | d49e6ccb837685e399efdef8b29e46cdc693ccec
#          Date/Time | 2023-04-12 19:54:58
#     OpenMP Threads | 4
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U235 from /home/rfp/kand/Openmc_godiva/hdf5_files/U235.h5
#  Reading U234 from /home/rfp/kand/Openmc_godiva/hdf5_files/U234.h5
#  Reading U238 from /home/rfp/kand/Openmc_godiva/hdf5_files/U238.h5
#  Minimum neutron data temperature: 294.0 K
#  Maximum neutron data temperature: 293.0 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000.0 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.34468
#         2/1    1.14950
#         3/1    1.06988
#         4/1    1.02983
#         5/1    1.01223
#         6/1    1.00454
#         7/1    0.99939
#         8/1    0.99639
#         9/1    0.99864
#        10/1    0.99508
#        11/1    0.99894
#        12/1    0.99738    0.99816 +/- 0.00078
#        13/1    0.99934    0.99855 +/- 0.00060
#        14/1    0.99732    0.99824 +/- 0.00052
#        15/1    0.99717    0.99803 +/- 0.00046
#        16/1    0.99629    0.99774 +/- 0.00047
#        17/1    0.99719    0.99766 +/- 0.00041
#        18/1    0.99885    0.99781 +/- 0.00038
#        19/1    0.99881    0.99792 +/- 0.00036
#        20/1    0.99975    0.99810 +/- 0.00037
#        21/1    1.00064    0.99834 +/- 0.00040
#        22/1    0.99719    0.99824 +/- 0.00038
#        23/1    0.99806    0.99823 +/- 0.00035
#        24/1    0.99572    0.99805 +/- 0.00037
#        25/1    0.99722    0.99799 +/- 0.00035
#        26/1    0.99740    0.99795 +/- 0.00033
#        27/1    0.99850    0.99799 +/- 0.00031
#        28/1    0.99903    0.99804 +/- 0.00030
#        29/1    0.99863    0.99808 +/- 0.00028
#        30/1    0.99773    0.99806 +/- 0.00027
#        31/1    0.99889    0.99810 +/- 0.00026
#        32/1    0.99796    0.99809 +/- 0.00025
#        33/1    0.99722    0.99805 +/- 0.00024
#        34/1    0.99872    0.99808 +/- 0.00023
#        35/1    0.99870    0.99811 +/- 0.00022
#        36/1    0.99680    0.99806 +/- 0.00022
#        37/1    0.99860    0.99808 +/- 0.00021
#        38/1    0.99747    0.99805 +/- 0.00021
#        39/1    0.99903    0.99809 +/- 0.00020
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.0591e-01 seconds
#    Reading cross sections          = 4.8749e-01 seconds
#  Total time in simulation          = 1.3542e+02 seconds
#    Time in transport only          = 1.1822e+02 seconds
#    Time in inactive batches        = 1.3253e+01 seconds
#    Time in active batches          = 1.2217e+02 seconds
#    Time synchronizing fission bank = 1.3542e+01 seconds
#      Sampling source sites         = 1.2783e+01 seconds
#      SEND/RECV source sites        = 7.5922e-01 seconds
#    Time accumulating tallies       = 1.5783e-04 seconds
#    Time writing statepoints        = 1.0026e-01 seconds
#  Total time for finalization       = 7.3000e-07 seconds
#  Total time elapsed                = 1.3627e+02 seconds
#  Calculation Rate (inactive)       = 452723.0 particles/second
#  Calculation Rate (active)         = 442023.0 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.99822 +/- 0.00015
#  k-effective (Track-length)  = 0.99821 +/- 0.00013
#  k-effective (Absorption)    = 0.99843 +/- 0.00016
#  Combined k-effective        = 0.99831 +/- 0.00009
#  Leakage Fraction            = 0.57083 +/- 0.00007
#
# 0.9983115557524982
# [0.993483547695267, 0.9848445906553273, 0.9930565360805824, 0.9969152623054934, 1.0222773244133994, 0.9912972370050633, 1.0074626150974915, 1.015609669770395, 0.9896179099642766, 1.0048249609716058, 1.0087224677575293, 0.9816503398480056, 0.9847009188919785, 0.9913153841639967, 0.9810371245771218, 1.0068974817307235, 1.0115867521937896, 0.9928370986960287, 0.9747081655367869, 0.991373661019558, 0.9851482613624557, 1.0053380025206733, 0.98631624564955, 0.9750650778657174, 1.0073648695276765, 1.0099809370769297, 1.002229342276266, 0.9843970144937226, 0.9846110253068349, 0.9798904069323533, 0.997712631990232, 0.9955560751508116, 0.974374104867594, 0.9861482889534356, 0.9884744295341907, 0.9955247424118671, 0.9853261216818388, 0.9956071940574711, 1.0038494690748043, 0.9872930784807128, 0.9721797791514929, 0.9988051695832034, 0.9943849681044195, 1.0016330018318098, 0.994557629974956, 0.9808319614306701, 0.9816074632773785, 1.0021483468215626, 1.0118771978586654, 0.9908889194057781, 0.9891376225108959, 0.9971704649908896, 0.9935707415714448, 0.9998501888915822, 0.9974038942723451, 1.01738152226187, 0.9797026110131473, 0.995638507360498, 0.9836822017591218, 1.0044725755096706, 0.9978022797309813, 1.0021483468216534, 0.9882451277325949, 0.9881548008628387, 1.001791559566723, 0.9874064397480232, 0.9864959321248492, 1.004001041008579, 1.0014889043485726, 0.9730940277767721, 0.9794884596879582, 0.9789291138427187, 0.9870817091271021, 0.9927704715919093, 0.9911166949203066, 0.9942148684043215, 0.9856568350892712, 0.9911187301575776, 0.9917416427047646, 0.9887608848766156, 0.9851685163952904, 0.9976565363546471, 1.0039497512580855, 0.9861962700052389, 0.9839064622927225, 0.9829397994899169, 0.9898071573444506, 0.9997621756146324, 0.9899995022574538, 0.99294051833654, 1.0186659072008328, 0.9845744597715519, 0.9979274952270015, 0.991499035254686, 1.0001948023911271, 1.0013496965327058, 0.9925682338482666, 0.9900319469315197, 0.9983115557524982]
